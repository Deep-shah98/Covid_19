# %%
% pylab inline

import numpy as np
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train = pd.read_csv("covid_19_data.csv")

# %%
train['Confirmed'].unique()
# Out:
# array([1.0000e+00, 1.4000e+01, 6.0000e+00, 0.0000e+00, 2.6000e+01,
#        2.0000e+00, 4.0000e+00, 5.0000e+00, 4.4400e+02, 9.0000e+00,
#        1.0000e+01, 2.2000e+01, 3.2000e+01, 3.0000e+00, 7.0000e+00,
#        1.6000e+01, 8.0000e+00, 2.7000e+01, 5.4900e+02, 5.3000e+01,
#        4.3000e+01, 3.6000e+01, 2.4000e+01, 2.3000e+01, 2.0000e+01,
#        1.8000e+01, 1.5000e+01, 7.6100e+02, 7.8000e+01, 6.2000e+01,
#        5.7000e+01, 4.1000e+01, 3.9000e+01, 3.3000e+01, 2.8000e+01,
#        1.9000e+01, 1.7000e+01, 1.1000e+01, 1.0580e+03, 1.1100e+02,
#        1.0400e+02, 8.3000e+01, 7.5000e+01, 6.9000e+01, 6.8000e+01,
#        6.0000e+01, 4.6000e+01, 4.4000e+01, 4.0000e+01, 3.5000e+01,
#        2.1000e+01, 1.3000e+01, 1.4230e+03, 1.5100e+02, 1.2800e+02,
#        1.1000e+02, 1.0000e+02, 8.0000e+01, 7.2000e+01, 7.0000e+01,
#        5.9000e+01, 4.7000e+01, 3.5540e+03, 2.0700e+02, 1.7300e+02,
#        1.6800e+02, 1.4300e+02, 1.3200e+02, 1.0900e+02, 1.0600e+02,
# ...

# %%
train['Recovered'].unique()
# Out:
# array([0.0000e+00, 2.8000e+01, 2.0000e+00, 3.1000e+01, 1.0000e+00,
#        3.2000e+01, 4.2000e+01, 4.5000e+01, 4.0000e+00, 3.0000e+00,
#        8.0000e+01, 5.0000e+00, 8.8000e+01, 9.0000e+01, 1.0000e+01,
#        1.4100e+02, 1.4000e+01, 1.1000e+01, 7.0000e+00, 9.0000e+00,
#        1.6800e+02, 2.1000e+01, 8.0000e+00, 6.0000e+00, 2.9500e+02,
#        1.5000e+01, 1.6000e+01, 1.2000e+01, 3.8600e+02, 4.3000e+01,
#        2.2000e+01, 1.8000e+01, 5.2200e+02, 6.2000e+01, 3.0000e+01,
#        2.7000e+01, 2.0000e+01, 2.3000e+01, 6.3300e+02, 4.9000e+01,
#        7.8000e+01, 4.7000e+01, 5.4000e+01, 2.4000e+01, 1.3000e+01,
#        8.1700e+02, 6.9000e+01, 9.4000e+01, 5.6000e+01, 8.1000e+01,
#        3.7000e+01, 3.4000e+01, 2.5000e+01, 1.1150e+03, 1.2300e+02,
#        8.6000e+01, 1.1200e+02, 3.3000e+01, 1.7000e+01, 1.4390e+03,
#        1.7500e+02, 1.1600e+02, 1.5600e+02, 5.9000e+01, 5.5000e+01,
#        5.1000e+01, 3.9000e+01, 4.4000e+01, 6.0000e+01, 4.1000e+01,
# ...

# %%
train['Deaths'].unique()
# Out:
# array([0.000e+00, 1.700e+01, 1.000e+00, 2.400e+01, 4.000e+01, 5.200e+01,
#        7.600e+01, 1.250e+02, 2.000e+00, 1.620e+02, 2.040e+02, 2.490e+02,
#        3.500e+02, 4.140e+02, 4.790e+02, 5.490e+02, 6.180e+02, 3.000e+00,
#        6.990e+02, 7.800e+02, 4.000e+00, 5.000e+00, 8.710e+02, 6.000e+00,
#        9.740e+02, 7.000e+00, 1.068e+03, 8.000e+00, 1.310e+03, 1.000e+01,
#        9.000e+00, 1.457e+03, 1.100e+01, 1.596e+03, 1.300e+01, 1.696e+03,
#        1.789e+03, 1.600e+01, 1.921e+03, 1.900e+01, 2.029e+03, 1.200e+01,
#        2.144e+03, 2.346e+03, 2.495e+03, 2.563e+03, 2.615e+03, 2.641e+03,
#        2.000e+01, 2.600e+01, 2.682e+03, 2.100e+01, 3.400e+01, 2.727e+03,
#        2.900e+01, 4.300e+01, 2.761e+03, 2.200e+01, 5.400e+01, 2.803e+03,
#        2.800e+01, 6.600e+01, 2.835e+03, 7.900e+01, 7.700e+01, 2.871e+03,
#        3.500e+01, 1.070e+02, 9.200e+01, 2.902e+03, 1.480e+02, 2.931e+03,
#        4.200e+01, 1.240e+02, 1.970e+02, 2.959e+03, 4.400e+01, 2.330e+02,
# ...

# %%
train.describe(include="all")
# Out:
#                 SNo ObservationDate Province/State  Country/Region  \
# count   6722.000000            6722           3956            6722
# unique          NaN              57            276             179
# top             NaN      03/18/2020          Hebei  Mainland China
# freq            NaN             284             59            1765
# mean    3361.500000             NaN            NaN             NaN
# std     1940.618587             NaN            NaN             NaN
# min        1.000000             NaN            NaN             NaN
# 25%     1681.250000             NaN            NaN             NaN
# 50%     3361.500000             NaN            NaN             NaN
# 75%     5041.750000             NaN            NaN             NaN
# max     6722.000000             NaN            NaN             NaN
#
#                 Last Update     Confirmed       Deaths     Recovered
# count                  6722   6722.000000  6722.000000   6722.000000
# ...

# %%
train.describe()
# Out:
#                SNo     Confirmed       Deaths     Recovered
# count  6722.000000   6722.000000  6722.000000   6722.000000
# mean   3361.500000    601.195924    19.855846    226.341267
# std    1940.618587   4896.332140   204.486922   2556.035202
# min       1.000000      0.000000     0.000000      0.000000
# 25%    1681.250000      2.000000     0.000000      0.000000
# 50%    3361.500000     13.000000     0.000000      0.000000
# 75%    5041.750000    108.000000     1.000000     11.000000
# max    6722.000000  67800.000000  3122.000000  56927.000000

# %%
train['Confirmed'].hist(bins=20)

# %%
train['Confirmed'].value_counts()
# Out:
# 1.0        1356
# 2.0         565
# 3.0         287
# 4.0         203
# 5.0         165
# 0.0         143
# 6.0         116
# 7.0         113
# 10.0        110
# 18.0         96
# 8.0          92
# 9.0          86
# 16.0         74
# 13.0         63
# 12.0         62
# 11.0         61
# 15.0         51
# 75.0         50
# 21.0         45
# 19.0         43
# 22.0         39
# 17.0         38
# 14.0         37
# 168.0        34
# 93.0         33
# 45.0         32
# 76.0         31
# 146.0        31
# 133.0        31
# 23.0         31
#            ...
# 1351.0        1
# 35713.0       1
# 573.0         1
# 551.0         1
# 11364.0       1
# 511.0         1
# 24953.0       1
# 4585.0        1
# 469.0         1
# 702.0         1
# 514.0         1
# 541.0         1
# 520.0         1
# 912.0         1
# 568.0         1
# 188.0         1
# 180.0         1
# 272.0         1
# 232.0         1
# 864.0         1
# 216.0         1
# 1209.0        1
# 665.0         1
# 643.0         1
# ...

# %%
train['Recovered'].value_counts()
# Out:
# 0.0        3474
# 1.0         723
# 2.0         259
# 4.0         164
# 3.0         123
# 8.0          71
# 5.0          63
# 18.0         59
# 12.0         57
# 10.0         43
# 16.0         41
# 6.0          41
# 7.0          40
# 9.0          37
# 22.0         28
# 15.0         24
# 14.0         22
# 73.0         20
# 31.0         18
# 24.0         18
# 13.0         18
# 17.0         17
# 30.0         16
# 71.0         16
# 11.0         15
# 20.0         14
# 78.0         14
# 27.0         13
# 43.0         13
# 88.0         13
#            ...
# 851.0         1
# 1966.0        1
# 983.0         1
# 4774.0        1
# 1237.0        1
# 783.0         1
# 679.0         1
# 1274.0        1
# 242.0         1
# 290.0         1
# 744.0         1
# 300.0         1
# 228.0         1
# 108.0         1
# 1081.0        1
# 15299.0       1
# 2134.0        1
# 405.0         1
# 319.0         1
# 1028.0        1
# 1181.0        1
# 1033.0        1
# 714.0         1
# 995.0         1
# ...

# %%
train['Recovered'].value_counts()
# Out:
# 0.0        3474
# 1.0         723
# 2.0         259
# 4.0         164
# 3.0         123
# 8.0          71
# 5.0          63
# 18.0         59
# 12.0         57
# 10.0         43
# 16.0         41
# 6.0          41
# 7.0          40
# 9.0          37
# 22.0         28
# 15.0         24
# 14.0         22
# 73.0         20
# 31.0         18
# 24.0         18
# 13.0         18
# 17.0         17
# 30.0         16
# 71.0         16
# 11.0         15
# 20.0         14
# 78.0         14
# 27.0         13
# 43.0         13
# 88.0         13
#            ...
# 851.0         1
# 1966.0        1
# 983.0         1
# 4774.0        1
# 1237.0        1
# 783.0         1
# 679.0         1
# 1274.0        1
# 242.0         1
# 290.0         1
# 744.0         1
# 300.0         1
# 228.0         1
# 108.0         1
# 1081.0        1
# 15299.0       1
# 2134.0        1
# 405.0         1
# 319.0         1
# 1028.0        1
# 1181.0        1
# 1033.0        1
# 714.0         1
# 995.0         1
# ...

# %%
train['Confirmed'].hist()

# %%
train['Recovered'].hist()

# %%
train['Deaths'].hist()

# %%
train.boxplot(column='Confirmed')

# %%
train.boxplot(column='Recovered')

# %%
train.boxplot(column='Deaths')

# %%
train.boxplot(column='Confirmed', by='Deaths')

# %%
train.boxplot(column='Confirmed', by='Recovered')

# %%
train['Deaths'].mode()[0]
# Out:
# 0.0

# %%
train['Confirmed'].mode()[0]
# Out:
# 1.0

# %%
train['Recovered'].mode()[0]
# Out:
# 0.0

# %%
train['Confirmed'].max()
# Out:
# 67800.0

# %%
train['Recovered'].max()
# Out:
# 56927.0

# %%
train['Deaths'].max()
# Out:
# 3122.0
